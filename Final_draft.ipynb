# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.preprocessing import LabelEncoder,RobustScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score,classification_report
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import RandomForestClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24368\2209948186.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sn
# ----> 5 from sklearn.preprocessing import LabelEncoder,RobustScaler
#       6 from sklearn.model_selection import train_test_split
#       7 from imblearn.over_sampling import SMOTE
#
# ~\anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py in <module>
#      23 from .murmurhash import murmurhash3_32
#      24 from .class_weight import compute_class_weight, compute_sample_weight
# ---> 25 from . import _joblib
#      26 from ..exceptions import DataConversionWarning
#      27 from .deprecation import deprecated
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_joblib.py in <module>
#       5     # joblib imports may raise DeprecationWarning on certain Python
#       6     # versions
# ----> 7     import joblib
#       8     from joblib import logger
#       9     from joblib import dump, load
#
# ~\anaconda3\lib\site-packages\joblib\__init__.py in <module>
#     118 from .numpy_pickle import load
#     119 from .compressor import register_compressor
# --> 120 from .parallel import Parallel
#     121 from .parallel import delayed
#     122 from .parallel import cpu_count
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <module>
#      28                                  LokyBackend)
#      29 from .externals.cloudpickle import dumps, loads
# ---> 30 from ._utils import eval_expr
#      31
#      32 # Make sure that those two classes are part of the public joblib.parallel API
#
# ModuleNotFoundError: No module named 'joblib._utils'

# %%
pip install xgboost
# Out:
# Collecting xgboostNote: you may need to restart the kernel to use updated packages.
#
#   Downloading xgboost-1.7.3-py3-none-win_amd64.whl (89.1 MB)
#      ---------------------------------------- 89.1/89.1 MB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\phoneclicker\anaconda3\lib\site-packages (from xgboost) (1.9.1)
# Requirement already satisfied: numpy in c:\users\phoneclicker\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.3

# %%
data=pd.read_csv("Churn.csv")
data
# Out:
#       Unnamed: 0 state      area.code  account.length voice.plan  \
# 0              1    KS  area_code_415             128        yes
# 1              2    OH  area_code_415             107        yes
# 2              3    NJ  area_code_415             137         no
# 3              4    OH  area_code_408              84         no
# 4              5    OK  area_code_415              75         no
# ...          ...   ...            ...             ...        ...
# 4995        4996    HI  area_code_408              50        yes
# 4996        4997    WV  area_code_415             152         no
# 4997        4998    DC  area_code_415              61         no
# 4998        4999    DC  area_code_510             109         no
# 4999        5000    VT  area_code_415              86        yes
#
#       voice.messages intl.plan  intl.mins  intl.calls  intl.charge  ...  \
# 0                 25        no       10.0           3         2.70  ...
# 1                 26        no       13.7           3         3.70  ...
# 2                  0        no       12.2           5         3.29  ...
# 3                  0       yes        6.6           7         1.78  ...
# 4                  0       yes       10.1           3         2.73  ...
# ...              ...       ...        ...         ...          ...  ...
# 4995              40        no        9.9           5         2.67  ...
# 4996               0        no       14.7           2         3.97  ...
# 4997               0        no       13.6           4         3.67  ...
# 4998               0        no        8.5           6         2.30  ...
# 4999              34        no        9.3          16         2.51  ...
#
#       day.calls  day.charge eve.mins eve.calls  eve.charge  night.mins  \
# 0           110       45.07    197.4        99       16.78       244.7
# 1           123       27.47    195.5       103       16.62       254.4
# 2           114       41.38    121.2       110       10.30       162.6
# 3            71        50.9     61.9        88        5.26       196.9
# 4           113       28.34    148.3       122       12.61       186.9
# ...         ...         ...      ...       ...         ...         ...
# 4995        127       40.07      223       126       18.96       297.5
# 4996         90       31.31    256.8        73       21.83       213.6
# 4997         89        23.9    172.8       128       14.69       212.4
# 4998         67        32.1    171.7        92       14.59       224.4
# 4999        102          22    267.1       104       22.70       154.8
#
#       night.calls  night.charge  customer.calls  churn
# 0              91         11.01               1     no
# 1             103         11.45               1     no
# 2             104          7.32               0     no
# 3              89          8.86               2     no
# 4             121          8.41               3     no
# ...           ...           ...             ...    ...
# 4995          116         13.39               2     no
# 4996          113          9.61               3    yes
# 4997           97          9.56               1     no
# 4998           89         10.10               0     no
# 4999          100          6.97               0     no
#
# [5000 rows x 21 columns]

# %%
data['eve.mins']=pd.to_numeric(data['eve.mins'],errors='coerce')
data['day.charge']=pd.to_numeric(data['day.charge'],errors='coerce')

# %%
data.dropna(axis=0,inplace=True)
data.shape
# Out:
# (4969, 21)

# %%
data=data.drop(columns=['Unnamed: 0','state','area.code'])

# %%
encoder=LabelEncoder()
data['intl.plan']=encoder.fit_transform(data['intl.plan'])
data['voice.plan']=encoder.fit_transform(data['intl.plan'])
data['churn']=encoder.fit_transform(data['churn'])

# %%
data['Total_Charge'] =  data['day.charge'] + data['eve.charge'] + data['night.charge']
data.drop(['day.charge','eve.charge','night.charge'],axis=1,inplace=True)

# %%
 data.columns = [s.replace('.','_') for s in data.columns]

# %%
data
# Out:
#       account_length  voice_plan  voice_messages  intl_plan  intl_mins  \
# 0                128           0              25          0       10.0
# 1                107           0              26          0       13.7
# 2                137           0               0          0       12.2
# 3                 84           1               0          1        6.6
# 4                 75           1               0          1       10.1
# ...              ...         ...             ...        ...        ...
# 4995              50           0              40          0        9.9
# 4996             152           0               0          0       14.7
# 4997              61           0               0          0       13.6
# 4998             109           0               0          0        8.5
# 4999              86           0              34          0        9.3
#
#       intl_calls  intl_charge  day_mins  day_calls  eve_mins  eve_calls  \
# 0              3         2.70     265.1        110     197.4         99
# 1              3         3.70     161.6        123     195.5        103
# 2              5         3.29     243.4        114     121.2        110
# 3              7         1.78     299.4         71      61.9         88
# 4              3         2.73     166.7        113     148.3        122
# ...          ...          ...       ...        ...       ...        ...
# 4995           5         2.67     235.7        127     223.0        126
# 4996           2         3.97     184.2         90     256.8         73
# 4997           4         3.67     140.6         89     172.8        128
# 4998           6         2.30     188.8         67     171.7         92
# 4999          16         2.51     129.4        102     267.1        104
#
#       night_mins  night_calls  customer_calls  churn  Total_Charge
# 0          244.7           91               1      0         72.86
# 1          254.4          103               1      0         55.54
# 2          162.6          104               0      0         59.00
# 3          196.9           89               2      0         65.02
# 4          186.9          121               3      0         49.36
# ...          ...          ...             ...    ...           ...
# 4995       297.5          116               2      0         72.42
# 4996       213.6          113               3      1         62.75
# 4997       212.4           97               1      0         48.15
# 4998       224.4           89               0      0         56.79
# 4999       154.8          100               0      0         51.67
#
# [4969 rows x 16 columns]

# %%
x=data.drop(columns=['churn'])
y=data['churn']

# %%
scale=RobustScaler()
x=scale.fit_transform(x)
x
# Out:
# array([[ 0.51851852,  0.        ,  1.47058824, ..., -0.34615385,
#          0.        ,  1.16008615],
#        [ 0.12962963,  0.        ,  1.52941176, ...,  0.11538462,
#          0.        , -0.08327351],
#        [ 0.68518519,  0.        ,  0.        , ...,  0.15384615,
#         -1.        ,  0.16511127],
#        ...,
#        [-0.72222222,  0.        ,  0.        , ..., -0.11538462,
#          0.        , -0.6137832 ],
#        [ 0.16666667,  0.        ,  0.        , ..., -0.42307692,
#         -1.        ,  0.00646088],
#        [-0.25925926,  0.        ,  2.        , ...,  0.        ,
#         -1.        , -0.36109117]])

# %%
x,y = SMOTE().fit_resample(x,y)
y.value_counts()
# Out:
# 0    4264
# 1    4264
# Name: churn, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=12)

# %%
# Define the parameters you want to tune
parameters = {
    'learning_rate': [0.1, 0.01, 0.001],
    'max_depth': [0, 1, 3, 5, 7, 9],
    'n_estimators': [50, 100, 200 , 500]
}

# Create a XGBoost classifier
xgb_clf = xgb.XGBClassifier()

# Use GridSearchCV to find the best parameters
clf = GridSearchCV(xgb_clf, parameters, cv=5)

# Fit the classifier to the training data
clf.fit(x_train, y_train)

# Print the best parameters
print("Best parameters found: ", clf.best_params_)
# Out:
# C:\Users\phoneclicker\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 60 fits failed out of a total of 360.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1490, in fit
#     self._Booster = train(
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [11:37:05] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1490, in fit
#     self._Booster = train(
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [11:37:06] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1490, in fit
#     self._Booster = train(
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [11:39:54] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1490, in fit
#     self._Booster = train(
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [11:43:20] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1490, in fit
#     self._Booster = train(
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\phoneclicker\anaconda3\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [11:43:21] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\phoneclicker\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan 0.88054975 0.88195697
#  0.88758503 0.89524604 0.9326141  0.95372117 0.97170104 0.97686046
#  0.95356492 0.9691992  0.97529711 0.97951867 0.96138279 0.97232677
#  0.97764257 0.97904967 0.965291   0.97357762 0.97654821 0.97889354
#         nan        nan        nan        nan 0.73531042 0.80644388
#  0.88054975 0.88054975 0.90384529 0.90447078 0.90462703 0.93167526
#  0.93370883 0.9341777  0.93636642 0.95215733 0.94637278 0.9462164
#  0.94574765 0.96106944 0.94965647 0.94809299 0.94762424 0.96404027
#         nan        nan        nan        nan 0.69277719 0.69293357
#  0.69293357 0.73279259 0.90368892 0.90384529 0.90384529 0.90384529
#  0.93480221 0.93480221 0.93480221 0.93464633 0.94715464 0.94699827
#  0.94746763 0.94637278 0.94527964 0.94621763 0.94965659 0.94965659]
#   warnings.warn(
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}

# %%
xgbclf=XGBClassifier(learning_rate=0.1,max_depth=5,n_estimators=500,random_state=42)
xgbclf.fit(x_train,y_train)
y_pred = xgbclf.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1062
#            1       1.00      0.95      0.97      1070
#
#     accuracy                           0.97      2132
#    macro avg       0.98      0.97      0.97      2132
# weighted avg       0.98      0.97      0.97      2132

# %%
parameters = {
    'criterion':['gini','entropy'],
    'max_depth': [3, 5, 7, 9],
    'n_estimators': [100, 200, 500]
}

model1=RandomForestClassifier()

gscv=GridSearchCV(model1,parameters,cv=5)
gscv.fit(x_train,y_train)

#print("Best parameters found: ", gscv.best_params_)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 9],
#                          'n_estimators': [100, 200, 500]})

# %%
print("Best parameters found: ", gscv.best_params_)
# Out:
# Best parameters found:  {'criterion': 'gini', 'max_depth': 9, 'n_estimators': 100}

# %%
model1=RandomForestClassifier(n_estimators=100,max_samples=0.8,random_state=12)
model1.fit(x_train,y_train)
y_pred=model1.predict(x_test)

print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.96      1130
#            1       0.93      1.00      0.96      1002
#
#     accuracy                           0.96      2132
#    macro avg       0.96      0.97      0.96      2132
# weighted avg       0.97      0.96      0.96      2132

# %%
model1=RandomForestClassifier(criterion= 'entropy',n_estimators=100,max_depth=9,random_state=12)
model1.fit(x_train,y_train)
y_pred=model1.predict(x_test)

print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94      1199
#            1       0.87      1.00      0.93       933
#
#     accuracy                           0.93      2132
#    macro avg       0.93      0.94      0.93      2132
# weighted avg       0.94      0.93      0.93      2132

# %%
data
# Out:
#       account_length  voice_plan  voice_messages  intl_plan  intl_mins  \
# 0                128           0              25          0       10.0
# 1                107           0              26          0       13.7
# 2                137           0               0          0       12.2
# 3                 84           1               0          1        6.6
# 4                 75           1               0          1       10.1
# ...              ...         ...             ...        ...        ...
# 4995              50           0              40          0        9.9
# 4996             152           0               0          0       14.7
# 4997              61           0               0          0       13.6
# 4998             109           0               0          0        8.5
# 4999              86           0              34          0        9.3
#
#       intl_calls  intl_charge  day_mins  day_calls  eve_mins  eve_calls  \
# 0              3         2.70     265.1        110     197.4         99
# 1              3         3.70     161.6        123     195.5        103
# 2              5         3.29     243.4        114     121.2        110
# 3              7         1.78     299.4         71      61.9         88
# 4              3         2.73     166.7        113     148.3        122
# ...          ...          ...       ...        ...       ...        ...
# 4995           5         2.67     235.7        127     223.0        126
# 4996           2         3.97     184.2         90     256.8         73
# 4997           4         3.67     140.6         89     172.8        128
# 4998           6         2.30     188.8         67     171.7         92
# 4999          16         2.51     129.4        102     267.1        104
#
#       night_mins  night_calls  customer_calls  churn  Total_Charge
# 0          244.7           91               1      0         72.86
# 1          254.4          103               1      0         55.54
# 2          162.6          104               0      0         59.00
# 3          196.9           89               2      0         65.02
# 4          186.9          121               3      0         49.36
# ...          ...          ...             ...    ...           ...
# 4995       297.5          116               2      0         72.42
# 4996       213.6          113               3      1         62.75
# 4997       212.4           97               1      0         48.15
# 4998       224.4           89               0      0         56.79
# 4999       154.8          100               0      0         51.67
#
# [4969 rows x 16 columns]

# %%
data.columns
# Out:
# Index(['account_length', 'voice_plan', 'voice_messages', 'intl_plan',
#        'intl_mins', 'intl_calls', 'intl_charge', 'day_mins', 'day_calls',
#        'eve_mins', 'eve_calls', 'night_mins', 'night_calls', 'customer_calls',
#        'churn', 'Total_Charge'],
#       dtype='object')

# %% [markdown]
# # Pickle File

# %%
import pickle
# creating a pickle file
filename = 'Final_draft.sav'
pickle.dump(model1,open(filename, 'wb'))

# %%
# loading the saved model 
loaded_model = pickle.load(open('Final_draft.sav','rb'))
